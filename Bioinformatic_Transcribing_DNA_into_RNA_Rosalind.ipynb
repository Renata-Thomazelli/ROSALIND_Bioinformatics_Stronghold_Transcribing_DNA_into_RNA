# %% [markdown]
# # <font color=red>Transcribing DNA into RNA<font>

# %% [markdown]
# So we have the DNA primary structure of a nucleic acid we have a second nucleic acid called RNA. As you must remember that the DNA we have a sequence as in RNA this sequence is a little different so instead we have Uracil we have Thymine molecules.
# In this exercise, we have to replace all the Thymine molecules with the Uracil molecules.

# %%
DNA_string="..."

# %%
RNA_string=DNA_string.replace("T","U")

# %%
print(RNA_string)
# Out:
# ...

# %% [markdown]
# This is [a Bioinformatics Problem from Rosalind site][Rosalind]
#
# [Rosalind]: http://rosalind.info/problems/rna/ "Rosalind Transcribing DNA into RNA"
